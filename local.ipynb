# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio===0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# !git clone https://github.com/WongKinYiu/yolov7

# %%
# !cd yolov5 & pip install -r requirements.txt

# %%
# !pip install ultralytics --user

# %%
# !pip install opencv-contrib-python

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
# %matplotlib inline

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\OgRob/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-6-14 Python-3.9.12 torch-1.8.1+cu111 CUDA:0 (NVIDIA GeForce GTX 1050, 2048MiB)
#
# ...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
cap = cv2.VideoCapture(0)
# cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
len(results.render())
# Out:
# 1

# %%
results.render()[0].shape
# Out:
# (480, 640, 3)

# %%
results
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 480x640 6 bottles, 1 bed
# Speed: 2.0ms pre-process, 23.0ms inference, 3.0ms NMS per image at shape (1, 3, 480, 640)

# %%
plt.imshow(results.render()[0])

# %%
import time

# %%
start = time.time()
results = model(frame)
end = time.time()
print(1/(end-start))
# Out:
# 35.71535376414588

# %%
model.eval()
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    start = time.time()
    results = model(frame)
    end = time.time()
    
    fps = 'fps: ' + str(round(1/(end-start)))
    result = np.squeeze(results.render())
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(result, fps, (7, 40), font, 1, (100, 255, 0), 3, cv2.LINE_AA)
    
    cv2.imshow('YOLO', result)
    

    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
plt.imshow(cv2.cvtColor(results.render()[0], cv2.COLOR_BGR2RGB))

# %% [markdown]
# ### Создание датасета

# %%
import uuid   # Unique identifier
import os
import time

# %%
# !mkdir custom_data

# %%
IMAGES_PATH = os.path.join('yolov5', 'custom_data', 'images', 'train') #/data/images
labels = ['engaged', 'disengaged']
number_imgs = 10

# %%
IMAGES_PATH = os.path.join('yolov5', 'custom_data', 'images', 'val') #/data/images

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
label = labels[0]
print(f'Collecting images for {label}')
time.sleep(5)

# Loop through image range
for img_num in range(number_imgs):
    print(f'Collecting images for {label}, image number {img_num}')

    # Webcam feed
    ret, frame = cap.read()

    # Naming out image path
    imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')

    # Writes out image to file 
    cv2.imwrite(imgname, frame)

    # Render to the screen
    cv2.imshow('Image Collection', frame)

    # 2 second delay between captures
    time.sleep(2)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
label = labels[1]
print(f'Collecting images for {label}')
time.sleep(5)

# Loop through image range
for img_num in range(number_imgs):
    print(f'Collecting images for {label}, image number {img_num}')

    # Webcam feed
    ret, frame = cap.read()

    # Naming out image path
    imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')

    # Writes out image to file 
    cv2.imwrite(imgname, frame)

    # Render to the screen
    cv2.imshow('Image Collection', frame)

    # 2 second delay between captures
    time.sleep(2)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# аналогично с валидацией

# %%
IMAGES_PATH = os.path.join('yolov5', 'custom_data', 'images', 'val') #/data/images
labels = ['engaged', 'disengaged']
number_imgs = 10

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
label = labels[1]
print(f'Collecting images for {label}')
time.sleep(5)

# Loop through image range
for img_num in range(number_imgs):
    print(f'Collecting images for {label}, image number {img_num}')

    # Webcam feed
    ret, frame = cap.read()

    # Naming out image path
    imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')

    # Writes out image to file 
    cv2.imwrite(imgname, frame)

    # Render to the screen
    cv2.imshow('Image Collection', frame)

    # 2 second delay between captures
    time.sleep(2)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...

# %%
# !pip install pyqt5 lxml --upgrade --user

# %% [markdown]
# Выполнил в консоли

# %%
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# ‘ЁбвҐ¬Ґ ­Ґ г¤ Ґвбп ­ ©вЁ гЄ § ­­л© Їгвм.

# %% [markdown]
# Затем python labelImg.py
#
# размечаем файлы

# %% [markdown]
# #### Предсказание в live. yolov5

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
# %matplotlib inline

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/best_yolo5s.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\OgRob/.cache\torch\hub\master.zip
# YOLOv5  2023-6-15 Python-3.9.12 torch-1.8.1+cu111 CUDA:0 (NVIDIA GeForce GTX 1050, 2048MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients
# Adding AutoShape...

# %%
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)
ret, frame = cap.read()

# %%
import time
from yolov5.utils.general import non_max_suppression
model.eval()
model.to('cuda')
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    start = time.time()
    results = model(frame)
    end = time.time()
    
#     results = non_max_suppression(results.pred, conf_thres=0.25, iou_thres=0.45)
    
    fps = 'fps: ' + str(round(1/(end-start)))
    result = np.squeeze(results.render())
    font = cv2.FONT_HERSHEY_SIMPLEX
    
    cv2.putText(result, fps, (7, 40), font, 1, (100, 255, 0), 3, cv2.LINE_AA)
    
    cv2.imshow('YOLO', result)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
results.pred
# Out:
# [tensor([[374.87256,  45.43616, 550.25098, 346.34592,   0.67731,  15.00000],
#          [130.50626,   0.00000, 357.41965, 380.14569,   0.60925,  16.00000],
#          [130.12561,   4.27553, 355.10529, 381.07684,   0.59104,  15.00000]], device='cuda:0')]

# %%
plt.imshow(cv2.cvtColor(results.render()[0], cv2.COLOR_BGR2RGB))

# %%
def calc_iou(first_bbox, second_bbox):

    first_bbox = first_bbox[[1,0, 3, 2]]
    second_bbox = second_bbox[[1,0, 3, 2]]
    
    inter_x_start = max(first_bbox[0], second_bbox[0])
    inter_y_start = max(first_bbox[1], second_bbox[1])
    inter_x_end = min(first_bbox[0] + first_bbox[2], second_bbox[0] + second_bbox[2])
    inter_y_end = min(first_bbox[1] + first_bbox[3], second_bbox[1] + second_bbox[3])

    area_inter = abs(max((inter_x_end - inter_x_start, 0)) * max((inter_y_end - inter_y_start), 0))
    
    if area_inter == 0:
        return 0.0

    area_first = abs(first_bbox[2] * first_bbox[3])
    area_second = abs(second_bbox[2] * second_bbox[3])
    
    return area_inter / (area_first + area_second - area_inter)

# %%
def nms(detections_list, iou_thr=0.5):
    detections = sorted(detections_list[0], key=lambda x: x[-2], reverse=True)

    suppressed_idx = []

    for idx, fi_box in enumerate(detections):
        if idx in suppressed_idx:
            continue

        for jdx in range(idx + 1, len(detections)):
            if jdx in suppressed_idx:
                continue

            se_box = detections[jdx]
            iou = calc_iou(fi_box[:-2], se_box[:-2])

            if iou > iou_thr:
                suppressed_idx.append(jdx)

    new_detections = []
    for idx, detection in enumerate(detections):
        if(idx not in suppressed_idx):
            new_detections.append(detection.unsqueeze(0))
            
    return new_detections

# %%
import time
from yolov5.utils.general import non_max_suppression
model.eval()
model.to('cuda')
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    start = time.time()
    results = model(frame)
    end = time.time()
    
    results.pred = nms(results.pred, iou_thr=0.5)
    
    fps = 'fps: ' + str(round(1/(end-start)))
    result = np.squeeze(results.render())
    font = cv2.FONT_HERSHEY_SIMPLEX
    
    cv2.putText(result, fps, (7, 40), font, 1, (100, 255, 0), 3, cv2.LINE_AA)
    
    cv2.imshow('YOLO', result)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
results.pred
# Out:
# [tensor([[257.09521,  91.40953, 464.07269, 443.49481,   0.92809,  16.00000]], device='cuda:0')]

# %%
nms(results.pred, iou_thr=0.5)[0].shape
# Out:
# torch.Size([1, 6])

# %%
nms(results.pred)
# Out:
# [tensor([241.46869,  82.17342, 442.64130, 397.86804,   0.68065,  15.00000], device='cuda:0')]

# %%
# %matplotlib inline

# %%
plt.imshow(cv2.cvtColor(results.render()[0], cv2.COLOR_BGR2RGB))

# %% [markdown]
# ### yolov7

# %%
model = torch.hub.load('WongKinYiu/yolov7', 'custom', 'yolov7/best_yolov7tiny.pt',
                        force_reload=True)
# Out:
# Downloading: "https://github.com/WongKinYiu/yolov7/archive/master.zip" to C:\Users\OgRob/.cache\torch\hub\master.zip
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2, None, 1, LeakyReLU(negative_slope=0.1)]
#   2                -1  1      2112  models.common.Conv                      [64, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   3                -2  1      2112  models.common.Conv                      [64, 32, 1, 1, None, 1, LeakyReLU(negative_slope=0.1)]
#   4                -1  1      9280  models.common.Conv                      [32, 32, 3, 1, None, 1, LeakyReLU(negative_slope=0.1)]
# ...

# %%
import time
model.eval()
model.to('cuda')
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    start = time.time()
    results = model(frame)
    end = time.time()
    
    fps = 'fps: ' + str(round(1/(end-start)))
    result = np.squeeze(results.render())
    font = cv2.FONT_HERSHEY_SIMPLEX
    
    cv2.putText(result, fps, (7, 40), font, 1, (100, 255, 0), 3, cv2.LINE_AA)
    
    cv2.imshow('YOLO', result)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
results

# %% [markdown]
# ### Сайт

# %%
# !pip install streamlit streamlit_webrtc

# %%
# !streamlit run ui.py
# Out:
# ^C
